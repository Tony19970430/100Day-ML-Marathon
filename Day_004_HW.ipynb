# %% [markdown]
# ## 練習時間
# 資料的操作有很多，接下來的馬拉松中我們會介紹常被使用到的操作，參加者不妨先自行想像一下，第一次看到資料，我們一般會想知道什麼訊息？
#
# #### Ex: 如何知道資料的 row 數以及 column 數、有什麼欄位、多少欄位、如何截取部分的資料等等
#
# 有了對資料的好奇之後，我們又怎麼通過程式碼來達成我們的目的呢？
#
# #### 可參考該[基礎教材](https://bookdata.readthedocs.io/en/latest/base/01_pandas.html#DataFrame-%E5%85%A5%E9%97%A8)或自行 google

# %% [markdown]
# # [作業目標]
# - 熟悉更多的 Python 資料操作

# %% [markdown]
# # [作業重點]
# - 列出資料的大小 (In[4], Hint : shape)
# - 列出所有欄位 (In[5], 有多種寫法)
# - 擷取部分資料 (In[6], Hint : loc 或 iloc)

# %%
import os
import numpy as np
import pandas as pd

# %%
os.listdir()
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  'Day_001_HW.ipynb',
#  'Day_002_HW.ipynb',
#  'Day_003_HW.ipynb',
#  'Day_004_HW.ipynb',
#  'Part01',
#  'README.md']

# %%
# 設定 data_path
dir_data = './/Part01'

# %%
f_app = os.path.join(dir_data, 'application_train.csv')
print('Path of read in data: %s' % (f_app))
app_train = pd.read_csv(f_app)
# Out:
# Path of read in data: .//Part01\application_train.csv

# %% [markdown]
# ### 如果沒有想法，可以先嘗試找出剛剛例子中提到的問題的答案
# #### 資料的 row 數以及 column 數

# %%
print('No. of rows')
print(len(app_train))
print('No. of columns')
print(len(app_train.columns))
# Out:
# No. of rows
# 307511
# No. of columns
# 122

# %% [markdown]
# #### 列出所有欄位

# %%
app_train.columns
# Out:
# Index(['SK_ID_CURR', 'TARGET', 'NAME_CONTRACT_TYPE', 'CODE_GENDER',
#        'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL',
#        'AMT_CREDIT', 'AMT_ANNUITY',
#        ...
#        'FLAG_DOCUMENT_18', 'FLAG_DOCUMENT_19', 'FLAG_DOCUMENT_20',
#        'FLAG_DOCUMENT_21', 'AMT_REQ_CREDIT_BUREAU_HOUR',
#        'AMT_REQ_CREDIT_BUREAU_DAY', 'AMT_REQ_CREDIT_BUREAU_WEEK',
#        'AMT_REQ_CREDIT_BUREAU_MON', 'AMT_REQ_CREDIT_BUREAU_QRT',
#        'AMT_REQ_CREDIT_BUREAU_YEAR'],
#       dtype='object', length=122)

# %% [markdown]
# #### 截取部分資料

# %%
app_train.sample(4000)
# Out:
#         SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 239635      377496       0         Cash loans           F            N
# 118753      237708       1    Revolving loans           M            N
# 123098      242745       0         Cash loans           F            N
# 59879       169418       0    Revolving loans           M            Y
# 67765       178588       0         Cash loans           M            Y
# ...            ...     ...                ...         ...          ...
# 205111      337766       0         Cash loans           F            N
# 266836      409140       1         Cash loans           M            N
# 232721      369543       0         Cash loans           F            N
# 108159      225470       0    Revolving loans           M            Y
# 205250      337924       0         Cash loans           F            N
#
#        FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# 239635               Y             0           90000.0    278712.0
# 118753               N             0          135000.0    180000.0
# 123098               Y             0          157500.0    630000.0
# 59879                Y             1          131706.0    135000.0
# 67765                Y             0           72000.0    808650.0
# ...                ...           ...               ...         ...
# 205111               Y             0          171000.0    592560.0
# 266836               Y             0           90000.0    450000.0
# 232721               Y             0           90000.0    508495.5
# 108159               N             1          405000.0    315000.0
# 205250               N             0          247500.0     90000.0
#
#         AMT_ANNUITY  ...  FLAG_DOCUMENT_18 FLAG_DOCUMENT_19 FLAG_DOCUMENT_20  \
# 239635       9031.5  ...                 0                0                0
# 118753       9000.0  ...                 0                0                0
# 123098      36166.5  ...                 0                0                0
# 59879        6750.0  ...                 1                0                0
# 67765       26217.0  ...                 0                0                0
# ...             ...  ...               ...              ...              ...
# 205111      28638.0  ...                 0                0                0
# 266836      20979.0  ...                 0                0                0
# 232721      24592.5  ...                 0                0                0
# 108159      15750.0  ...                 0                0                0
# 205250       7213.5  ...                 0                0                0
#
#        FLAG_DOCUMENT_21 AMT_REQ_CREDIT_BUREAU_HOUR AMT_REQ_CREDIT_BUREAU_DAY  \
# 239635                0                        0.0                       0.0
# 118753                0                        0.0                       0.0
# 123098                0                        0.0                       0.0
# 59879                 0                        NaN                       NaN
# 67765                 0                        0.0                       0.0
# ...                 ...                        ...                       ...
# 205111                0                        0.0                       0.0
# 266836                0                        0.0                       0.0
# 232721                0                        0.0                       0.0
# 108159                0                        0.0                       0.0
# 205250                0                        0.0                       0.0
#
#         AMT_REQ_CREDIT_BUREAU_WEEK  AMT_REQ_CREDIT_BUREAU_MON  \
# 239635                         0.0                        0.0
# 118753                         0.0                        1.0
# 123098                         0.0                        0.0
# 59879                          NaN                        NaN
# 67765                          0.0                        0.0
# ...                            ...                        ...
# 205111                         0.0                        0.0
# 266836                         0.0                        0.0
# 232721                         0.0                        0.0
# 108159                         0.0                        0.0
# 205250                         0.0                        1.0
#
#         AMT_REQ_CREDIT_BUREAU_QRT  AMT_REQ_CREDIT_BUREAU_YEAR
# 239635                        0.0                         5.0
# 118753                        0.0                         4.0
# 123098                        0.0                         3.0
# 59879                         NaN                         NaN
# 67765                         0.0                         0.0
# ...                           ...                         ...
# 205111                        0.0                         5.0
# 266836                        0.0                         1.0
# 232721                        0.0                         1.0
# 108159                        0.0                         1.0
# 205250                        0.0                         4.0
#
# [4000 rows x 122 columns]

# %% [markdown]
# #### 還有各種數之不盡的資料操作，重點還是取決於實務中遇到的狀況和你想問的問題，在馬拉松中我們也會陸續提到更多例子
